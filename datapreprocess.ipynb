# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv("C:/Users/varsh/Downloads/archive (2)/weatherAUS.csv")

# %%
data.shape
# Out:
# (145460, 23)

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
data.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.dropna().sum()
# Out:
# Date             2009-01-012009-01-022009-01-042009-01-052009-0...
# Location         CobarCobarCobarCobarCobarCobarCobarCobarCobarC...
# MinTemp                                                   759682.3
# MaxTemp                                                  1366447.6
# Rainfall                                                  120197.0
# Evaporation                                               310486.9
# Sunshine                                                  436444.0
# WindGustDir      SSWSNNEWNWWNWNSSWSEENENEEENESSWSWSWSSENNEWNWNW...
# WindGustSpeed                                            2306301.0
# WindDir9am       ENESSENNEWNWNWNSSEENENNESENENWSSNEENENNWNNNESS...
# WindDir3pm       SWSSENNWWSWWNWWNWSSESWSWWSWENENNNWSWSSWSENNENW...
# WindSpeed9am                                              883945.0
# WindSpeed3pm                                             1116370.0
# Humidity9am                                              3716618.0
# ...

# %%
df_cleaned = data.dropna()
df_cleaned.to_csv("cleaned_dataset.csv", index=False)

# %%
df_cleaned.shape
# Out:
# (56420, 23)

# %%
df=pd.read_csv("cleaned_dataset.csv")
df_random=df.sample(n=4000,random_state=42)
df_random.to_csv("random_4000_rows.csv",index=False)

# %%
df_random=pd.read_csv("random_4000_rows.csv")

# %%
df.isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Cloud9am         0
# Temp9am          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
print(df_random.shape)
num_df=df_random.select_dtypes(include=['int64','float64'] )
plt.figure(figsize=(25,10))
sns.heatmap(num_df.corr(),annot=True,fmt=".2f",cmap="coolwarm")
# Out:
# (4000, 23)
# <Axes: >

# %%
df_random.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           4000 non-null   object
#  1   Location       4000 non-null   object
#  2   MinTemp        4000 non-null   float64
#  3   MaxTemp        4000 non-null   float64
#  4   Rainfall       4000 non-null   float64
#  5   Evaporation    4000 non-null   float64
#  6   Sunshine       4000 non-null   float64
#  7   WindGustDir    4000 non-null   object
#  8   WindGustSpeed  4000 non-null   float64
#  9   WindDir9am     4000 non-null   object
#  10  WindDir3pm     4000 non-null   object
#  11  WindSpeed9am   4000 non-null   float64
#  12  WindSpeed3pm   4000 non-null   float64
#  13  Humidity9am    4000 non-null   float64
#  14  Humidity3pm    4000 non-null   float64
#  15  Pressure9am    4000 non-null   float64
#  16  Pressure3pm    4000 non-null   float64
# ...

# %%
df_random.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean     13.377025    24.010225     2.116850     5.406250     7.643425
# std       6.412765     6.965255     6.281318     3.625294     3.775725
# min      -4.400000     8.000000     0.000000     0.000000     0.000000
# 25%       8.500000    18.400000     0.000000     2.800000     4.900000
# 50%      13.100000    23.700000     0.000000     4.800000     8.400000
# 75%      18.300000    29.400000     0.800000     7.400000    10.700000
# max      28.800000    46.700000   106.400000    54.000000    14.500000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    4000.000000   4000.000000   4000.000000  4000.000000  4000.000000
# mean       41.063500     15.678250     19.841500    66.340250    50.364500
# std        13.542777      8.474089      8.649802    18.593289    20.289925
# ...

# %%
df_random.head(5)
# Out:
#          Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0  2011-12-03       Canberra      7.7     24.2       0.0          4.8
# 1  2008-08-17         Darwin     18.3     30.8       0.0          9.8
# 2  2015-09-25  NorfolkIsland     14.4     19.4       4.8          5.8
# 3  2013-08-23         Sydney     11.8     18.6       0.0          4.0
# 4  2014-10-06          Perth     10.8     19.4       8.8          4.4
#
#    Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0      13.2         NNW           39.0        NNW  ...        67.0
# 1      10.8           E           44.0         SE  ...        18.0
# 2      10.1           W           61.0         SW  ...        69.0
# 3       2.5         WNW           56.0         NW  ...        50.0
# 4      11.1           S           31.0        SSE  ...        56.0
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
cols_to_drop = ['Pressure3pm', 'Temp3pm', 'Cloud3pm']
df = df_random.drop(columns=[col for col in cols_to_drop if col in df_random.columns])
df.drop(columns=['Date','Location'], inplace=True)
df.shape
# Out:
# (4000, 18)

# %%
df.to_csv("finaldata_4000_row.csv")
df.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Cloud9am', 'Temp9am', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

skew_values = num_df.skew(numeric_only=True)

plt.figure(figsize=(10,6))
skew_values.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Skewness of Numeric Features", fontsize=14)
plt.xlabel("Features", fontsize=12)
plt.ylabel("Skewness", fontsize=12)
plt.xticks(rotation=45, ha="right")
plt.axhline(y=0, color='red', linestyle='--') 
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

num_df = df_random.select_dtypes(include=['int64', 'float64']).copy()

cols_to_square = ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
                  'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm',
                  'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Cloud9am', 'Temp9am']

for col in cols_to_square:
    if col in num_df.columns:
        num_df[col] = num_df[col] ** 2

skew_values = num_df.skew(numeric_only=True)

plt.figure(figsize=(10,6))
skew_values.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title("Skewness of Selected Numeric Columns", fontsize=14)
plt.xlabel("Features", fontsize=12)
plt.ylabel("Skewness", fontsize=12)
plt.xticks(rotation=45, ha="right")
plt.axhline(y=0, color='red', linestyle='--')  
plt.tight_layout()
plt.show()
