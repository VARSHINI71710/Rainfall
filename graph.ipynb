# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
df=pd.read_csv("finaldata_4000_row.csv")

# %%
y = df['RainTomorrow']
print(y.value_counts())
sns.countplot(x=y, palette="Set2")
plt.title("Class Distribution of RainTomorrow")
plt.show()
# Out:
# RainTomorrow
# No     3063
# Yes     937
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (4000, 19)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X= df.drop(columns=['RainTomorrow','WindGustDir','WindDir9am','WindDir3pm','RainToday'])
y = df['RainTomorrow']
X_res, y_res = smote.fit_resample(X, y)
print(y_res.value_counts())
sns.countplot(x=y_res, palette="Set2")
plt.title("Class Distribution of RainTomorrow")
plt.show()
# Out:
# RainTomorrow
# Yes    3063
# No     3063
# Name: count, dtype: int64

# %%
X_res.shape
# Out:
# (6126, 14)

# %%
sns.histplot(df['Rainfall'], kde=True, bins=30)
plt.title("Rainfall Distribution with KDE")
plt.show()

# %%
sns.histplot(df['Evaporation'], kde=True, bins=30)
plt.title("Rainfall Distribution with KDE")
plt.show()

# %%
sns.histplot(df['MaxTemp'], kde=True, bins=30)
plt.title("Rainfall Distribution with KDE")
plt.show()

# %%
sns.histplot(df['MinTemp'], kde=True, bins=30)
plt.title("Rainfall Distribution with KDE")
plt.show()

# %%
sns.histplot(df['Sunshine'], kde=True, bins=30)
plt.title("Rainfall Distribution with KDE")
plt.show()

# %%
sns.histplot(df['Humidity3pm'], kde=True, bins=30)
plt.title("Rainfall Distribution with KDE")
plt.show()

# %%
sns.histplot(df['Cloud9am'], kde=True, bins=30)
plt.title("Rainfall Distribution with KDE")
plt.show()
